# %%
import tweepy
import json
import boto3
from textblob import TextBlob
import re
from azure.iot.device import IoTHubDeviceClient, Message
import matplotlib.pyplot as plot
import mysql.connector
from mysql.connector import errorcode
from unidecode import unidecode
from datetime import datetime


# Chaves de API do Twitter
consumer_key = "8CNb9XmJ7KrjOLp8UMNH9Fznh"
consumer_secret = "eGoW01Xjhg1rslbOk23UYIPBsItB6Qr0cOA4SDmiXGekWfPmDB"
access_token = "2973742181-XBE1qdfNncM8zrb5shvdKHLcJa1fvhvahPKQGjX"
access_token_secret = "qRGj0HK2MIKWZHlIuiZ2oConS7yNPIRQwrqgoP0sAyI10"


# Autenticação com a API do Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Função para dividir o texto em unidades léxicas
def tokenize(text):
    # Utilize expressões regulares para encontrar palavras, símbolos e pontuação
    tokens = re.findall(r'\w+|[^\w\s]', text)
    return tokens

def insert_db_grupo(tweet, sentiment):
    try:
        mydb = mysql.connector.connect(
            user= "roott",
            password= "Urubu100",
            host= "frequenciacardiaca.mysql.database.azure.com",
            database= "Grupo3"
        )

        if mydb.is_connected():
            #db_Info = mydb.get_server_info()
            #print("Conectado ao MySQL Server versão ", db_Info)

            mycursor = mydb.cursor()

            sql_query = "INSERT INTO analise_twitter(fraseTweet,sentimentoTweet,origem) VALUES (%s,%s,%s)"
            val = [tweet, sentiment, "Fernando"]
            mycursor.execute(sql_query, val)

            mydb.commit()

            print(mycursor.rowcount, "registro inserido")

    except mysql.connector.Error as e:
        print("Erro ao conectar com o MySQL", e)
    finally:
        if(mydb.is_connected()):
            mycursor.close()
            mydb.close()
            #print("Conexão com MySQL está fechada\n")

def insert_db(tweet, sentiment):
    try:
        mydb = mysql.connector.connect(
            user= "roott",
            password= "Urubu100",
            host= "sensor-movimento.mysql.database.azure.com",
            database= "movimento"
        )

        if mydb.is_connected():
            #db_Info = mydb.get_server_info()
            #print("Conectado ao MySQL Server versão ", db_Info)

            mycursor = mydb.cursor()

            sql_query = "INSERT INTO analise_twitter(fraseTweet,sentimentoTweet) VALUES (%s,%s)"
            val = [tweet, sentiment]
            mycursor.execute(sql_query, val)

            mydb.commit()

            print(mycursor.rowcount, "registro inserido")

    except mysql.connector.Error as e:
        print("Erro ao conectar com o MySQL", e)
    finally:
        if(mydb.is_connected()):
            mycursor.close()
            mydb.close()
            #print("Conexão com MySQL está fechada\n")            

# Palavras para pesquisar
palavras_pesquisa = ["sono",
                     "dormir",
                     "hospital"]

# Consulta de tweets
query = " ".join(palavras_pesquisa)
tweets = api.search_tweets(q=query, tweet_mode="extended", count=10)

# Análise léxica e análise de sentimento

for tweet in tweets:
    if hasattr(tweet, "retweeted_status"):
        cleaned_text = tweet.retweeted_status.full_text
    else:
        cleaned_text = tweet.full_text
    
    tokens = tokenize(cleaned_text)
    
    analysis = TextBlob(cleaned_text)
    polarity = analysis.sentiment.polarity
    if polarity > 0:
        sentiment = "positivo"
        dados = {'fraseTweet': unidecode(cleaned_text), 'sentimentoTweet': sentiment}
    elif polarity < 0:
        sentiment = "negativo"
        dados = {'fraseTweet': unidecode(cleaned_text), 'sentimentoTweet': sentiment}
    else:
        sentiment = "neutro"
        dados = {'fraseTweet': unidecode(cleaned_text), 'sentimentoTweet': sentiment}

    insert_db(cleaned_text, sentiment)
    insert_db_grupo(cleaned_text, sentiment)    
    
    # Verifica se alguma das palavras de pesquisa está presente no texto do tweet
    if any(palavra.lower() in cleaned_text.lower() for palavra in palavras_pesquisa):
        print(f"Tweet: {cleaned_text}")
        print("Unidades Léxicas:")
        for token in tokens:
            print(token)
        print(f"Sentimento: {sentiment}")
        print()
        print(dados)
# Out:
# Erro ao conectar com o MySQL 1366 (HY000): Incorrect string value: '\xF0\x9F\xA4\xA1' for column 'fraseTweet' at row 1
# 1 registro inserido
# Tweet: Sonhei que tive trigêmeos com meu ex e fui parindo dentro de casa e dentro do carro até chegar no hospital... Tive três pesadelos em um só, dormir mal a noite e agr tô morrendo de sono 🤡
# Unidades Léxicas:
# Sonhei
# que
# tive
# trigêmeos
# com
# meu
# ex
# e
# fui
# parindo
# dentro
# de
# casa
# e
# dentro
# do
# carro
# até
# chegar
# no
# hospital
# .
# .
# .
# Tive
# três
# pesadelos
# em
# um
# só
# ,
# dormir
# mal
# a
# noite
# e
# agr
# tô
# morrendo
# de
# sono
# 🤡
# Sentimento: neutro
#
# {'fraseTweet': 'Sonhei que tive trigemeos com meu ex e fui parindo dentro de casa e dentro do carro ate chegar no hospital... Tive tres pesadelos em um so, dormir mal a noite e agr to morrendo de sono ', 'sentimentoTweet': 'neutro'}
# Erro ao conectar com o MySQL 1366 (HY000): Incorrect string value: '\xF0\x9F\xA4\xA6\xF0\x9F...' for column 'fraseTweet' at row 1
# 1 registro inserido
# Tweet: To caindo de sono mas não consigo dormir nesse hospital 🤦🏽‍♀️
# Unidades Léxicas:
# To
# caindo
# de
# sono
# mas
# não
# consigo
# dormir
# nesse
# hospital
# 🤦
# 🏽
# ‍
# ♀
# ️
# Sentimento: neutro
#
# {'fraseTweet': 'To caindo de sono mas nao consigo dormir nesse hospital ', 'sentimentoTweet': 'neutro'}
# Erro ao conectar com o MySQL 1366 (HY000): Incorrect string value: '\xF0\x9F\xA4\xA1\x0AF...' for column 'fraseTweet' at row 1
# 1 registro inserido
# Tweet: Quinta feira já volto das férias,vai ser um sofrimento pra ajustar meu horário de sono
# Tô indo dormir as 07h00 e essa hora normalmente eu tô chegando no hospital 🤡
# Fiquei com uma leve saudade das minhas crianças do almox
# Unidades Léxicas:
# Quinta
# feira
# já
# volto
# das
# férias
# ,
# vai
# ser
# um
# sofrimento
# pra
# ajustar
# meu
# horário
# de
# sono
# Tô
# indo
# dormir
# as
# 07h00
# e
# essa
# hora
# normalmente
# eu
# tô
# chegando
# no
# hospital
# 🤡
# Fiquei
# com
# uma
# leve
# saudade
# das
# minhas
# crianças
# do
# almox
# Sentimento: neutro
#
# {'fraseTweet': 'Quinta feira ja volto das ferias,vai ser um sofrimento pra ajustar meu horario de sono \nTo indo dormir as 07h00 e essa hora normalmente eu to chegando no hospital \nFiquei com uma leve saudade das minhas criancas do almox', 'sentimentoTweet': 'neutro'}
# 1 registro inserido
# 1 registro inserido
# Tweet: crente e igreja são uma praga mesmo, quando minha insônia tava na pior fase eu desmaiei 2 vezes pq cheguei num ponto onde fiquei tanto tempo sem dormir que meu corpo não aguentava mais e apagava.
#
# fui ao hospital, cheguei lá a mulher mandou eu rezar pedindo uma boa noite de sono. https://t.co/rRpo6fy4hu
# Unidades Léxicas:
# crente
# e
# igreja
# são
# uma
# praga
# mesmo
# ,
# quando
# minha
# insônia
# tava
# na
# pior
# fase
# eu
# desmaiei
# 2
# vezes
# pq
# cheguei
# num
# ponto
# onde
# fiquei
# tanto
# tempo
# sem
# dormir
# que
# meu
# corpo
# não
# aguentava
# mais
# e
# apagava
# .
# fui
# ao
# hospital
# ,
# cheguei
# lá
# a
# mulher
# mandou
# eu
# rezar
# pedindo
# uma
# boa
# noite
# de
# sono
# .
# https
# :
# /
# /
# t
# .
# co
# /
# rRpo6fy4hu
# Sentimento: neutro
#
# {'fraseTweet': 'crente e igreja sao uma praga mesmo, quando minha insonia tava na pior fase eu desmaiei 2 vezes pq cheguei num ponto onde fiquei tanto tempo sem dormir que meu corpo nao aguentava mais e apagava.\n\nfui ao hospital, cheguei la a mulher mandou eu rezar pedindo uma boa noite de sono. https://t.co/rRpo6fy4hu', 'sentimentoTweet': 'neutro'}
# 1 registro inserido
# 1 registro inserido
# Tweet: como é ruim dormir em hospital viu tentando colocar meu sono em dia já faz 2 dias
# Unidades Léxicas:
# como
# é
# ruim
# dormir
# em
# hospital
# viu
# tentando
# colocar
# meu
# sono
# em
# dia
# já
# faz
# 2
# dias
# Sentimento: neutro
#
# {'fraseTweet': 'como e ruim dormir em hospital viu tentando colocar meu sono em dia ja faz 2 dias', 'sentimentoTweet': 'neutro'}
# Erro ao conectar com o MySQL 1366 (HY000): Incorrect string value: '\xF0\x9F\x98\xB4\xF0\x9F...' for column 'fraseTweet' at row 1
# 1 registro inserido
# Tweet: Ontem cheguei do hospital tão cansada que dormir cedinho e ainda continuo com sono, pqp 😴😴
# Unidades Léxicas:
# Ontem
# cheguei
# do
# hospital
# tão
# cansada
# que
# dormir
# cedinho
# e
# ainda
# continuo
# com
# sono
# ,
# pqp
# 😴
# 😴
# Sentimento: neutro
#
# {'fraseTweet': 'Ontem cheguei do hospital tao cansada que dormir cedinho e ainda continuo com sono, pqp ', 'sentimentoTweet': 'neutro'}
# 1 registro inserido
# 1 registro inserido
# Tweet: O sono não vem amanhã tenho que tá as seis no hospital trabalhar estar as treze horas em casa arrumar a casa pra receber prestadores de serviço e não consigo dormir amanhã eu vou acordar e enfiar 3 cápsulas de café no meio do meu cu e ainda trabalhar de Home pq tem IRPF
# Unidades Léxicas:
# O
# sono
# não
# vem
# amanhã
# tenho
# que
# tá
# as
# seis
# no
# hospital
# trabalhar
# estar
# as
# treze
# horas
# em
# casa
# arrumar
# a
# casa
# pra
# receber
# prestadores
# de
# serviço
# e
# não
# consigo
# dormir
# amanhã
# eu
# vou
# acordar
# e
# enfiar
# 3
# cápsulas
# de
# café
# no
# meio
# do
# meu
# cu
# e
# ainda
# trabalhar
# de
# Home
# pq
# tem
# IRPF
# Sentimento: neutro
#
# {'fraseTweet': 'O sono nao vem amanha tenho que ta as seis no hospital trabalhar estar as treze horas em casa arrumar a casa pra receber prestadores de servico e nao consigo dormir amanha eu vou acordar e enfiar 3 capsulas de cafe no meio do meu cu e ainda trabalhar de Home pq tem IRPF', 'sentimentoTweet': 'neutro'}
# 1 registro inserido
# 1 registro inserido
# Tweet: é muito exaustivo e desgastante, nem sono regulado e uma saúde boa eu tenho kk domingo retrasado mesmo fui pro hospital tomar soro, vou dormir quase sempre tardão de madrugada, às vezes até viro a noite, minha ansiedade me faz tremer pirar a cabeça e até passar mal+++
# Unidades Léxicas:
# é
# muito
# exaustivo
# e
# desgastante
# ,
# nem
# sono
# regulado
# e
# uma
# saúde
# boa
# eu
# tenho
# kk
# domingo
# retrasado
# mesmo
# fui
# pro
# hospital
# tomar
# soro
# ,
# vou
# dormir
# quase
# sempre
# tardão
# de
# madrugada
# ,
# às
# vezes
# até
# viro
# a
# noite
# ,
# minha
# ansiedade
# me
# faz
# tremer
# pirar
# a
# cabeça
# e
# até
# passar
# mal
# +
# +
# +
# Sentimento: neutro
#
# {'fraseTweet': 'e muito exaustivo e desgastante, nem sono regulado e uma saude boa eu tenho kk domingo retrasado mesmo fui pro hospital tomar soro, vou dormir quase sempre tardao de madrugada, as vezes ate viro a noite, minha ansiedade me faz tremer pirar a cabeca e ate passar mal+++', 'sentimentoTweet': 'neutro'}
# 1 registro inserido
# 1 registro inserido
# Tweet: essa madrugada precisei ir no hospital, tava sozinha e dirigindo, a médica passou um remédio que da sono e pediu pra eu tomar e voar pra casa pra chegar bem, o enfermeiro pediu pelo amor de Deus pra eu não dormir parando em nenhum sinal, simplesmente vim pra casa com o cu na mao
# Unidades Léxicas:
# essa
# madrugada
# precisei
# ir
# no
# hospital
# ,
# tava
# sozinha
# e
# dirigindo
# ,
# a
# médica
# passou
# um
# remédio
# que
# da
# sono
# e
# pediu
# pra
# eu
# tomar
# e
# voar
# pra
# casa
# pra
# chegar
# bem
# ,
# o
# enfermeiro
# pediu
# pelo
# amor
# de
# Deus
# pra
# eu
# não
# dormir
# parando
# em
# nenhum
# sinal
# ,
# simplesmente
# vim
# pra
# casa
# com
# o
# cu
# na
# mao
# Sentimento: neutro
#
# {'fraseTweet': 'essa madrugada precisei ir no hospital, tava sozinha e dirigindo, a medica passou um remedio que da sono e pediu pra eu tomar e voar pra casa pra chegar bem, o enfermeiro pediu pelo amor de Deus pra eu nao dormir parando em nenhum sinal, simplesmente vim pra casa com o cu na mao', 'sentimentoTweet': 'neutro'}
# 1 registro inserido
# 1 registro inserido
# Tweet: Fui dormir às 23:00 e tinha que acordas as 5:00, mas como to ansiosa pra prova de amanhã, acordei as 3:30. Agr to com sono e cansada, tenho que ser útil no hospital e ainda estudar quando chegar em casa
# Unidades Léxicas:
# Fui
# dormir
# às
# 23
# :
# 00
# e
# tinha
# que
# acordas
# as
# 5
# :
# 00
# ,
# mas
# como
# to
# ansiosa
# pra
# prova
# de
# amanhã
# ,
# acordei
# as
# 3
# :
# 30
# .
# Agr
# to
# com
# sono
# e
# cansada
# ,
# tenho
# que
# ser
# útil
# no
# hospital
# e
# ainda
# estudar
# quando
# chegar
# em
# casa
# Sentimento: neutro
#
# {'fraseTweet': 'Fui dormir as 23:00 e tinha que acordas as 5:00, mas como to ansiosa pra prova de amanha, acordei as 3:30. Agr to com sono e cansada, tenho que ser util no hospital e ainda estudar quando chegar em casa', 'sentimentoTweet': 'neutro'}

# %%
json_lexico = json.dumps(dados)
print(json_lexico)
# Out:
# {"fraseTweet": "Fui dormir as 23:00 e tinha que acordas as 5:00, mas como to ansiosa pra prova de amanha, acordei as 3:30. Agr to com sono e cansada, tenho que ser util no hospital e ainda estudar quando chegar em casa", "sentimentoTweet": "neutro"}

# %%
session = boto3.Session()

s3 = session.client('s3')

bucket_name = 'raw-dev-fernando'
file_name = 'lexico-2023/05/29.json'

s3.put_object(Body=json_lexico, Bucket=bucket_name, Key=file_name)
# Out:
# {'ResponseMetadata': {'RequestId': '5QDWTRMR4GC6ZTXA',
#   'HostId': 'WruxgEQIc3xZW07YOw8anRoscpZ/xQwpYC9woURm2JwqMz7wLJ2NwysdN0vhjzBTuahlpD2Av10=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'WruxgEQIc3xZW07YOw8anRoscpZ/xQwpYC9woURm2JwqMz7wLJ2NwysdN0vhjzBTuahlpD2Av10=',
#    'x-amz-request-id': '5QDWTRMR4GC6ZTXA',
#    'date': 'Tue, 30 May 2023 00:47:51 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"23625cfdc5223f1fb0736ea71c31507a"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'ETag': '"23625cfdc5223f1fb0736ea71c31507a"',
#  'ServerSideEncryption': 'AES256'}

# %%
session = boto3.Session()

s3 = session.client('s3')

bucket_name = 'trusted-dev-fernando'
file_name = 'lexico-2023/05/29.json'

s3.put_object(Body=json_lexico, Bucket=bucket_name, Key=file_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'NQNHG881P1NY340M',
#   'HostId': 'bUI2USgDCBJOEN8vqh3BTQVDgmXxXpkNVIvS5d1D1gFr/O5nsV6cRd0ZDRkz6JlMMZnQllKU2r8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'bUI2USgDCBJOEN8vqh3BTQVDgmXxXpkNVIvS5d1D1gFr/O5nsV6cRd0ZDRkz6JlMMZnQllKU2r8=',
#    'x-amz-request-id': 'NQNHG881P1NY340M',
#    'date': 'Tue, 30 May 2023 00:47:52 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"23625cfdc5223f1fb0736ea71c31507a"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'ETag': '"23625cfdc5223f1fb0736ea71c31507a"',
#  'ServerSideEncryption': 'AES256'}

# %%
session = boto3.Session()

s3 = session.client('s3')

bucket_name = 'refined-dev-fernando'
file_name = 'lexico-2023/05/29.json'

s3.put_object(Body=json_lexico, Bucket=bucket_name, Key=file_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'NQNTVB171HJW7591',
#   'HostId': 'L4OfzhvietEL6YpNgTrQFJGH8dEnCXVv9wvYmxw9EAg8vRJyP34YF0A0jXOQkz56PPS7ZRtyHw0=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'L4OfzhvietEL6YpNgTrQFJGH8dEnCXVv9wvYmxw9EAg8vRJyP34YF0A0jXOQkz56PPS7ZRtyHw0=',
#    'x-amz-request-id': 'NQNTVB171HJW7591',
#    'date': 'Tue, 30 May 2023 00:47:52 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"23625cfdc5223f1fb0736ea71c31507a"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'ETag': '"23625cfdc5223f1fb0736ea71c31507a"',
#  'ServerSideEncryption': 'AES256'}
